# %%
import os
import pandas as pd
from pathlib import Path

# --- Parameters You Need to Set ---

# 1. The main folder containing all your experiment subdirectories
root_directory = '/home/eric/Documents/cervicalResearchIIP/result_test/MCUEffectivenessReal'

# 2. The exact name of the csv file you want to read from each directory
target_csv_name = 'Dice.csv'

# 3. The name of the column that holds the performance metric
performance_column_name = 'Dice_score'


# This list will store our results before creating the final DataFrame
results = []

results = []

print(f"Starting traversal of '{root_directory}'...")

# os.walk is the perfect tool for this. It goes into every subdirectory.
for dirpath, dirnames, filenames in os.walk(root_directory):
    # Check if our target CSV is in the list of files for the current directory
    if target_csv_name in filenames:
        experiment_name = os.path.basename(dirpath)
        file_path = os.path.join(dirpath, target_csv_name)
        
        try:
            # Read the CSV file, telling pandas there is NO header row
            temp_df = pd.read_csv(file_path, header=None)
            
            # Check if the DataFrame is not empty
            if not temp_df.empty:
                # Get the last value from the first row.
                # .iloc[0, -1] gets the item from the first row (index 0)
                # and the last column (index -1).
                last_performance_value = temp_df.iloc[0, -1]
                
                # Append the result as a dictionary to our list
                results.append({
                    'experiment': experiment_name,
                    'dice_score': last_performance_value
                })
                print(f"  [SUCCESS] Found and read data for '{experiment_name}'")
            else:
                 print(f"  [SKIPPED] File found for '{experiment_name}', but it is empty.")

        except Exception as e:
            # Catch potential errors like malformed files
            print(f"  [ERROR] Could not process file for '{experiment_name}'. Reason: {e}")

# Convert the list of dictionaries into a final, clean pandas DataFrame
mcu_df = pd.DataFrame(results)

print("\n--- Traversal Complete ---")
print("Final aggregated performance data:")
print(mcu_df)
 

# 1. The main folder containing all your experiment subdirectories
root_directory2 = '/home/eric/Documents/cervicalResearchIIP/result_test/UNetEffectivenessReal'

# 2. The exact name of the csv file you want to read from each directory
target_csv_name = 'Dice.csv'

# 3. The name of the column that holds the performance metric
performance_column_name = 'Dice_score'


# This list will store our results before creating the final DataFrame

results = []

print(f"Starting traversal of '{root_directory2}'...")

# os.walk is the perfect tool for this. It goes into every subdirectory.
for dirpath, dirnames, filenames in os.walk(root_directory2):
    # Check if our target CSV is in the list of files for the current directory
    if target_csv_name in filenames:
        experiment_name = os.path.basename(dirpath)
        file_path = os.path.join(dirpath, target_csv_name)
        
        try:
            # Read the CSV file, telling pandas there is NO header row
            temp_df = pd.read_csv(file_path, header=None)
            
            # Check if the DataFrame is not empty
            if not temp_df.empty:
                # Get the last value from the first row.
                # .iloc[0, -1] gets the item from the first row (index 0)
                # and the last column (index -1).
                last_performance_value = temp_df.iloc[0, -1]
                
                # Append the result as a dictionary to our list
                results.append({
                    'experiment': experiment_name,
                    'dice_score': last_performance_value
                })
                print(f"  [SUCCESS] Found and read data for '{experiment_name}'")
            else:
                 print(f"  [SKIPPED] File found for '{experiment_name}', but it is empty.")

        except Exception as e:
            # Catch potential errors like malformed files
            print(f"  [ERROR] Could not process file for '{experiment_name}'. Reason: {e}")

# Convert the list of dictionaries into a final, clean pandas DataFrame
u_df = pd.DataFrame(results)

print("\n--- Traversal Complete ---")
print("Final aggregated performance data:")
print(u_df)
mcu_df['dice_score'] = mcu_df['dice_score'] * 100
#mcu_df = mcu_df.drop(16)
print(f"Variance: {mcu_df['dice_score'].var()}")
print(f"Mean: {mcu_df['dice_score'].mean()}")
mcu_df
u_df['dice_score'] = u_df['dice_score'] * 100
print(f"Variance: {u_df['dice_score'].var()}")
print(f"Mean: {u_df['dice_score'].mean()}")
#u_df = u_df.drop(35)
u_df
# Out:
# Starting traversal of '/home/eric/Documents/cervicalResearchIIP/result_test/MCUEffectivenessReal'...
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-9662'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-34518'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-68617'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-21392'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-2252'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-77996'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-81452'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-18497'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-73667'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-81108'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-81020'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-19041'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-86325'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-22763'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-10260'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-78280'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-96154'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-36750'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-68029'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-13212'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-87907'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-38407'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-77461'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-65860'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-43460'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-69641'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-92639'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-65801'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-94515'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-38659'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-12557'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-95626'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-22657'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-74994'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-9621'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-36801'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-63622'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-92534'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-8195'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-22690'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-71781'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-65818'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-7884'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-2048'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-69422'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-23031'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-20198'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-76872'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-1582'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-3837'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-54466'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-6182'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-35112'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-71787'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-83761'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-15082'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-85096'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-22247'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-77134'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-79740'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-74888'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-64268'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-61754'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-41805'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-33245'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-86599'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-61935'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-46458'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-44659'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-2533'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-82488'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-65580'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-4595'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-57656'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-26275'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-26950'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-1929'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-50395'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-87077'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-71122'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-97462'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-16302'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-33731'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-54731'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-71712'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-23574'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-92497'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-18097'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-93118'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-80520'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-83985'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-6842'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-17321'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-53873'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-69800'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-79067'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-69111'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-68640'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-59545'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-5820'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-31984'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-2830'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-78591'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-91357'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-1382'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-34040'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-84366'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-65905'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-25424'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-50603'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-69886'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-29485'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-63198'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-60726'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-87497'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-92854'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-27727'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-83316'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-96021'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-98175'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-7980'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-35174'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-259'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-32021'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-37051'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-98538'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-30380'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-8724'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-41182'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-24216'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-65687'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-24486'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-53462'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-74144'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-28272'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-83877'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-53703'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-30058'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-84718'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-84863'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-61452'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-71955'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-9770'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-78572'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-38017'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-47306'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-53639'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-38981'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-10633'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-89092'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-94768'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-73837'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-11824'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-40374'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-42674'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-45817'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-67320'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-82720'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-21120'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-43428'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-51302'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-27803'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-10400'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-40464'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-28483'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-88943'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-76115'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-85097'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-63799'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-57454'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-77000'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-40535'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-46529'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-28561'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-69741'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-72510'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-23565'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-52769'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-22495'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-44585'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-11863'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-33966'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-43683'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-81689'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-71624'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-24451'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-38254'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-45594'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-82326'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-38964'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-51573'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-70051'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-34246'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-31585'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-24179'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-54070'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-94173'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-46853'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-54216'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-99565'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-88029'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-718'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-76982'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-51117'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-13629'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-19243'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-79287'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-10455'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-41111'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-50356'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-52796'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-20157'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-37683'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-67945'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-9986'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-61382'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-94601'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-85825'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-28292'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-28773'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-55510'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-62350'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-20097'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-18323'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-78293'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-40767'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-53887'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-38942'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-17275'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-47745'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-69781'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-84196'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-63237'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-88562'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-40550'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-74419'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-72350'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-13381'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-67690'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-70022'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-62356'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-62372'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-2670'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-74556'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-39438'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-49424'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-31812'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-22794'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-65'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-61886'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-9951'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-88691'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-8689'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-16547'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-4147'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-66249'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-68647'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-29708'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-21325'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-72755'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-47188'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-65769'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-18350'
#   [SUCCESS] Found and read data for '20250701-Study-MCUNet-58312'
#
# --- Traversal Complete ---
# Final aggregated performance data:
#                       experiment  dice_score
# 0     20250701-Study-MCUNet-9662    0.761889
# 1    20250701-Study-MCUNet-34518    0.895612
# 2    20250701-Study-MCUNet-68617    0.768919
# 3    20250701-Study-MCUNet-21392    0.826794
# 4     20250701-Study-MCUNet-2252    0.850573
# ..                           ...         ...
# 259  20250701-Study-MCUNet-72755    0.764659
# 260  20250701-Study-MCUNet-47188    0.785697
# 261  20250701-Study-MCUNet-65769    0.790178
# 262  20250701-Study-MCUNet-18350    0.827247
# 263  20250701-Study-MCUNet-58312    0.700354
#
# [264 rows x 2 columns]
# Starting traversal of '/home/eric/Documents/cervicalResearchIIP/result_test/UNetEffectivenessReal'...
#   [SUCCESS] Found and read data for '20250701-Study-UNet-51302'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-10400'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-7980'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-81108'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-54731'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-31984'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-68029'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-94601'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-55510'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-28272'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-53887'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-85097'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-38407'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-57656'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-50603'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-96154'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-63237'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-83761'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-27727'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-28773'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-46458'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-18097'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-87077'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-62372'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-38254'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-18497'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-83985'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-78293'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-61754'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-67945'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-60726'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-65580'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-91357'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-40464'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-65769'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-71955'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-50356'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-21392'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-10455'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-72510'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-63198'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-18323'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-82720'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-68617'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-2670'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-10633'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-22690'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-21325'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-81452'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-36750'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-16302'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-78280'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-24451'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-65905'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-4147'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-83877'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-70022'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-74144'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-66249'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-79740'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-98538'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-95626'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-82326'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-44659'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-54466'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-47745'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-69800'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-28561'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-97462'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-74994'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-259'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-96021'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-65687'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-65818'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-34246'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-35174'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-77134'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-53639'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-71624'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-46529'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-35112'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-19243'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-92534'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-2048'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-30380'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-76872'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-718'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-85096'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-21120'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-36801'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-20097'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-86325'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-73667'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-2533'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-84366'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-22657'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-87497'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-4595'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-61382'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-88029'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-63799'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-38964'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-67690'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-1929'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-87907'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-77461'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-2252'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-29485'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-88691'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-31585'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-1382'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-9770'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-64268'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-83316'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-47188'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-11863'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-41182'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-24179'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-79067'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-65860'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-51573'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-78572'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-85825'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-98175'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-92854'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-27803'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-81020'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-54070'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-38942'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-78591'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-34518'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-77996'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-9621'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-68640'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-73837'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-72350'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-8195'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-69781'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-79287'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-54216'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-53873'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-61935'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-69641'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-18350'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-99565'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-92497'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-88943'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-61886'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-46853'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-19041'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-58312'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-25424'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-89092'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-22794'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-33245'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-43428'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-24486'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-6842'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-23565'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-69111'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-62356'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-57454'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-10260'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-9662'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-23574'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-15082'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-7884'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-82488'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-30058'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-6182'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-69886'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-69741'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-76115'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-71781'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-84863'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-59545'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-77000'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-28292'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-9986'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-8724'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-53462'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-17321'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-33966'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-81689'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-38981'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-84196'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-80520'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-71712'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-26275'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-13629'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-86599'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-37683'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-13381'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-26950'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-69422'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-40374'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-65'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-3837'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-22247'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-40767'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-5820'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-29708'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-28483'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-63622'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-49424'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-93118'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-43683'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-40550'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-20198'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-38659'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-40535'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-92639'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-72755'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-61452'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-52796'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-45817'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-94173'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-68647'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-2830'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-50395'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-20157'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-94768'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-31812'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-42674'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-70051'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-32021'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-23031'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-8689'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-41805'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-74419'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-38017'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-51117'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-24216'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-33731'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-74888'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-65801'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-37051'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-71122'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-67320'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-94515'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-9951'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-12557'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-62350'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-47306'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-13212'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-41111'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-22495'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-1582'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-39438'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-45594'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-52769'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-76982'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-17275'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-84718'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-34040'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-11824'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-16547'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-71787'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-43460'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-74556'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-44585'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-22763'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-53703'
#   [SUCCESS] Found and read data for '20250701-Study-UNet-88562'
#
# --- Traversal Complete ---
# Final aggregated performance data:
#                     experiment  dice_score
# 0    20250701-Study-UNet-51302    0.649717
# 1    20250701-Study-UNet-10400    0.802299
# 2     20250701-Study-UNet-7980    0.772194
# 3    20250701-Study-UNet-81108    0.836982
# 4    20250701-Study-UNet-54731    0.699387
# ..                         ...         ...
# 259  20250701-Study-UNet-74556    0.692734
# 260  20250701-Study-UNet-44585    0.717229
# 261  20250701-Study-UNet-22763    0.765170
# 262  20250701-Study-UNet-53703    0.846716
# 263  20250701-Study-UNet-88562    0.739687
#
# [264 rows x 2 columns]
# Variance: 222.37006357269664
# Mean: 74.60673163483305
# Variance: 202.93785166840047
# Mean: 73.18266147784338
#                     experiment  dice_score
# 0    20250701-Study-UNet-51302   64.971677
# 1    20250701-Study-UNet-10400   80.229947
# 2     20250701-Study-UNet-7980   77.219381
# 3    20250701-Study-UNet-81108   83.698176
# 4    20250701-Study-UNet-54731   69.938701
# ..                         ...         ...
# 259  20250701-Study-UNet-74556   69.273447
# 260  20250701-Study-UNet-44585   71.722932
# 261  20250701-Study-UNet-22763   76.516994
# 262  20250701-Study-UNet-53703   84.671587
# 263  20250701-Study-UNet-88562   73.968717
#
# [264 rows x 2 columns]

# %%
unet_scores = u_df['dice_score'].values
mcunet_scores = mcu_df['dice_score'].values

# %%
print(unet_scores)
# Out:
# [64.97167704 80.2299469  77.21938119 83.69817602 69.93870126 79.16619963
#  78.91703887  6.69842697 72.0712439  77.19536379 74.35075414 83.17849008
#  67.80603905 82.89793824 76.93058082 68.79951457 80.57214286 85.44398298
#  78.61723451 77.9248633  77.80869141 67.02789918 43.45407613 49.68830584
#  80.41513843 43.32332412 49.65281739 69.38888743 57.66549994 67.31087318
#  67.43160398 78.99216379 83.02723632  7.72073816 75.8627705  68.79496115
#  52.43297812 82.60773391 72.48558773 22.69729701 78.24712644 74.45078769
#  77.28496796 68.92482574 65.34417024 71.45262027 77.77547714 80.52638005
#  76.27459805 81.85161135 85.73140288 72.53399876 80.90887504 80.7733307
#  77.12528037 54.44271773 84.50554674 79.0218314  73.64988376 75.27495501
#  78.73128445 75.86355142 70.10229166 71.76023254 42.27524937 79.52410767
#  78.85542875 71.1691417  81.26262795 77.57304344 78.39322515 78.62369279
#  75.14809677 75.76393242 68.71962011 68.26243285 80.93522971 85.96299391
#  70.4628871  80.70122497 85.85420268 73.16313033 83.38288921 11.91832511
#  83.20562494 79.40399079 63.02283229 72.6788455  84.27077193 79.11150652
#  81.80218385 82.19784256 72.06340348 67.18182887 80.82749474 82.22987437
#  80.02062007 78.77176251 76.04524104 69.46895006 67.46995357 76.74339762
#  75.69141724 72.93190586 70.91720607 70.64220342 81.07144882 85.70677941
#  76.59719896 78.16529694 25.67569672 74.12661024 83.61136367 67.03770316
#  76.18149168 77.56927232 66.2090034  76.97586547 60.89783159 78.48522162
#  73.40387912 81.72400501 75.23795953 68.28087079 78.82838509 78.96616864
#  67.35408776 70.90064984 84.32959731 87.52515816 73.4280256  72.27584792
#  75.5120467  71.36806759 86.74505    79.67564773 77.15056814 83.06704133
#  79.67818737 75.71498244 84.03120918 47.38747716 81.8084734  80.48281159
#  79.70778327 82.17539081 75.13423813 80.70302407 76.34011659 79.89892531
#  76.88054131 60.68870834  1.77001812 80.92296838 74.06106601 75.38784111
#  45.12481272 82.00342171 68.51759721 78.29508902 82.40796226 79.22766287
#  75.8354711  77.97339675 72.10363995 75.04998662 75.0988753  85.40584338
#  77.72513988 81.24112869 70.54429768 83.71177219 75.61009882 76.00697604
#  76.92724664 85.99596379 75.93872678 69.75479516 69.2152983  86.97134605
#  83.56317362 76.28161252 76.51362883 59.79925745 85.3213261  79.64211119
#  70.10859314 71.79670414 76.00964149 81.19112131 76.72074453 80.94776774
#  80.50396597 73.41834995 59.8125178  82.82809262 78.15670776 77.9028296
#  80.07863821 15.38291132 79.80818416 80.28253746 13.83405476 78.77938238
#  71.26129867 78.69435375 71.26972882 81.5007981  74.76996519 87.55329218
#  84.37850739 75.78084606 68.48063609 67.2126961  80.72473769 73.69062238
#  74.9785013  80.1957457  86.14047354  5.3513171  81.51774879 75.77242208
#  64.09794463 83.81549228 85.76149981 78.6387894  78.68912313 79.0352974
#  76.31165557 71.65283209 81.22113689 66.18229961 71.77414339 76.97472812
#  64.26383875 78.79265438 55.74319079 78.39174308 70.89261984 78.16786551
#  85.5441829  78.32555808 81.94606191 84.02297165 80.68735025 79.11410665
#  79.75474471 78.14288421 66.76178058 31.02355706 79.18026414 67.28163481
#  85.21136447 74.06654016 81.21002089 77.12066659 83.64292124 73.07504072
#  74.42438277 69.2734471  71.7229324  76.51699406 84.67158743 73.96871747]

# %%
print(mcunet_scores)
# Out:
# [76.18888104 89.56122275 76.89192215 82.67941125 85.05733561 77.67769056
#  82.76010086 78.47809659 78.42597364 80.86638407 79.06322217 79.77383816
#  38.62125507 68.94838838 72.38449277 82.19570092 79.8217418  67.3946199
#  80.18136885 48.39333531 67.32178047 71.35415117 80.26290888 76.64914688
#  75.20121596 78.59685956 73.57560674 79.13076112  1.09488381 84.76005886
#  74.27897227 70.88777715 79.02109891 78.03292482 80.4349603  75.23960679
#  15.02964533 81.83407966 56.51577917 83.47394798 79.00878772 75.35355486
#  77.64388243 18.07425381 81.97130345 83.86381581 77.66586959 76.45278758
#  62.11789747 74.80587839 69.24279729 69.3808873  75.9739063  77.44515899
#  82.38716391 74.21046136 78.75940362 80.16318243 78.90476315 81.21001887
#  75.39100065 84.02957833 80.83234068 69.45418054 82.46070603 77.30678381
#  85.1717582  17.88176369 79.29376001 78.24781584 78.78215368 84.72761312
#  83.18618691 78.63940957 61.61440413 84.30547832 78.28283782 13.7484786
#  65.83279228 79.42774371 86.11883522 82.89137348 78.20839523 83.59862811
#  76.06704839 81.43075101 68.60766461 71.38892418 77.43077045 70.26990372
#  75.67406315 76.83104351 70.83526412 83.76246144 60.90396915 67.06723786
#  87.91460106 76.21542819 77.32660406 80.10221353 82.47080067 86.63410611
#  79.66236928 85.05605362 74.98049446 81.44758369 70.86360757 82.16523262
#  80.58794312 89.49411821 76.65050201 86.31149785 76.61738837 80.24492751
#  82.75266483 86.53728055 65.55653786 75.52726142 79.48011002 75.83382098
#  79.86050038 83.16591209 71.92081653 85.00276637 44.62886252 74.35132178
#  82.47621637 80.11869736 73.08523443 82.58446095 75.10495931 87.83650012
#  76.1501871  86.53814951 71.8236949  80.45195651 19.45284186 75.94456556
#  73.81553476 68.49013768  5.86210551 77.26529939 14.89338213 65.39283989
#  82.13266741 81.15591267 82.52949912 74.23514891 83.33483598 84.86441705
#  60.88282377 72.10166514 61.14931979 78.72473059 72.25745991 84.22785136
#  75.7360391  80.40507138 40.78011268 85.13297353 78.05356686 77.87535858
#  83.17259375 80.69675887 79.90212687 59.89442479 78.38267084 82.60914782
#  85.59314713 79.45086043 83.93245682 83.72481735 82.17775309 80.2462175
#  78.62781582 63.76385272 87.9744727  85.81108753 80.14034227 84.21030795
#  79.2191866  75.46657945 67.95066749 45.88849252 79.15420874 77.40621533
#  81.44955771 72.11388967 78.30086657 77.14028999 85.26277416 16.53326153
#  84.2885556  62.80126049 79.10513082 78.32938537 67.07626006 75.78048114
#  75.74141855 83.89681517 70.03824507 84.70494569 80.47133307 76.52394708
#  80.4891504  82.77838296 36.19316973 83.51144352 76.04069906 72.1977471
#  79.08022954 85.46497247 87.10586767 75.38455414 66.34435674 77.47425221
#  71.29083922 86.19433927 71.00489057 84.8679829  84.75686871 72.94975768
#  83.37731929 77.00983302 80.09732757 86.01206205 85.69628178 85.70086123
#  84.39531022 79.47489717 74.36471261 79.49213483  8.24048525 80.08374069
#  84.26543751 82.41133208 73.24790944 80.83822947 48.42341507 86.59505123
#  77.7249979  77.62211473 77.53464718 72.92289363 81.876275   70.95963616
#  72.98098226 87.06795726 78.53614179 79.00817431 73.61120073 82.28143395
#  80.16198185 40.14492728 77.451243   80.92453113 83.35813826 77.99376024
#  84.76252187 76.46591239 78.56970809 79.01784114 82.72465977 70.03541918]

# %%
# diffs = mcunet_scores - unet_scores
# r = abs(np.median(diffs)) / np.std(diffs, ddof=1)  # r effect size approximation
# r

# %%
from statsmodels.stats.power import TTestPower

# %%
import numpy as np
from statsmodels.stats.power import TTestPower

def wilcoxon_sample_size_approximation(A, B, alpha=0.05, power=0.8, safety_factor=1.15, desired_diff = 4):
    """
    Estimate Wilcoxon sample size using t-test calculation + safety factor
    """
    print("Pilot data summary:")
    print(f"Algorithm A mean: {np.mean(A):.4f}")
    print(f"Algorithm B mean: {np.mean(B):.4f}")
    print(f"Difference in means: {abs(np.mean(A) - np.mean(B)):.4f}")
    print(f"Standard deviation of differences: {np.std(A-B, ddof=1):.4f}")

    # Step 1: Calculate Cohen's d as if it were a t-test
    diffs = A - B
    std_diffs = np.std(diffs, ddof=1)
    cohens_d = desired_diff / std_diffs
    #cohens_d = abs(np.mean(diffs) / np.std(diffs, ddof=1))
    
    # Step 2: CREATE INSTANCE FIRST, then call solve_power
    power_analysis = TTestPower()  # Create the instance
    n_ttest = power_analysis.solve_power(effect_size=cohens_d, 
                                        alpha=alpha, 
                                        power=power, 
                                        nobs=None,
                                        alternative='two-sided')
    
    # Step 3: Apply safety factor for non-parametric test
    n_wilcoxon = int(np.ceil(n_ttest * safety_factor))
    
    return n_wilcoxon, n_ttest, cohens_d

# Usage
n_wilcoxon, n_ttest, d = wilcoxon_sample_size_approximation(unet_scores, mcunet_scores)
print(f"T-test sample size: {n_ttest:.0f}")
print(f"Wilcoxon sample size (15% increase): {n_wilcoxon}")
print(f"Effect size (Cohen's d): {d:.3f}")
# Out:
# Pilot data summary:
# Algorithm A mean: 73.1827
# Algorithm B mean: 74.6067
# Difference in means: 1.4241
# Standard deviation of differences: 20.5557
# T-test sample size: 209
# Wilcoxon sample size (15% increase): 241
# Effect size (Cohen's d): 0.195
